# %% [markdown]
# # Q-diamond plot
# #### --- first steps ---
#
# (authored by JK, AC Sep 28th, 2025)
#
# This plotting routinge displays a n-qubit quantum state as a Hasse-type diagram with embedded probabilities. This is useful to debug algorithmic snippets of quantum circuits analytically.

# %%
import qmond_lib as qd
# %matplotlib inline

import sys
print(sys.executable)
# Out:
# C:\Users\Julia Kowalski\.conda\envs\qiskit-env\python.exe

# %% [markdown]
# #### A first test of the plotting routine starts with providing states

# %%
Default_Input = {
    (): 1.,
}
EPR0 = {
    (): 1.,
}
Bell01_1 = {
    (): 1.,
    (0,1): 1.,
}

# %% [markdown]
# #### Actual plotting routing - check out python file to understand arguments

# %%
number_of_qubits = 8
h_spacing = 0.5
v_spacing = 0.5
size = [h_spacing, v_spacing]

fig_init, ax_init = qd.plot_qbit_space(
    n = 3, # -- number of qubits --
    # -- you can pass over qubit state explicitely
    #prob={(): 0, (0,): 1, (1,): 2, (2,): 3},
    # -- or you make use of one of the previously initialized states
    prob = Default_Input, 
    # -- select what to display: "abs", real", "imag", or "phase" 
    prob_component = "abs",       
    tensor_bs_size = size,
    horizontal_spacing = h_spacing,
    vertical_spacing = v_spacing
)
